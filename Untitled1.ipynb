# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 Cu=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Customers.csv')
 Cu
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
Cu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
Cu.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %% [markdown]
# ***В качестве целевого признак выберем стобец "Spending Score" или же "Оценка расходов",который отображает покупательскую силу,т.е общую оценку клиента***

# %%
sns.countplot(data = Cu, x = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# По диаграме видно,что преобладает женский пол

# %%
sns.histplot(data=Cu,y="Work Experience",hue = 'Gender',palette='winter')
# Out:
# <Axes: xlabel='Count', ylabel='Work Experience'>

# %% [markdown]
# Можно заметить,что опыт работы ~до 2 лет часто встречающийся у покупателей,и как видно женщин больше с таким опытом работы

# %%
sns.histplot(data = Cu, y = 'Profession')
# Out:
# <Axes: xlabel='Count', ylabel='Profession'>

# %% [markdown]
# Как видно,популярная профессия это творческая(художник)

# %%
sns.barplot(data = Cu, x = 'Annual Income ($)',y='Profession')
# Out:
# <Axes: xlabel='Annual Income ($)', ylabel='Profession'>

# %% [markdown]
# Годовой доход самый маленький у профессии художник,наибольший у администратора

# %%
sns.barplot(data=Cu,x='Spending Score (1-100)',y='Profession')
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Profession'>

# %% [markdown]
# у профессий услуг развлечения(Entertaiment)самый большой показатель расходов и наоборот у домохозяек.

# %%
sns.lineplot(y='Annual Income ($)', x='Spending Score (1-100)',  data = Cu)
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Annual Income ($)'>

# %% [markdown]
# Можно сказать,что доход как раз влияет на показатель расходов, в среднем он ~120000

# %%
print(Cu["Profession"].value_counts())
# Out:
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: Profession, dtype: int64

# %% [markdown]
# количество покупателей каждой профессии

# %%
sns.barplot(data = Cu, y = 'Profession',x='Work Experience')
# Out:
# <Axes: xlabel='Work Experience', ylabel='Profession'>

# %% [markdown]
# Заметим,что опыт работы наибольший у домохозяек,а наименьший у профессий услуг

# %%
sns.countplot(data = Cu, x = 'Family Size')
# Out:
# <Axes: xlabel='Family Size', ylabel='count'>

# %% [markdown]
# Видно,что больше всего покупателей с размером семьи в 2 человека,далее идет уменьшенее

# %%
sns.lineplot(x='Spending Score (1-100)', y='Family Size',  data = Cu)
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Family Size'>

# %%
Cu.corr()
# Out:
#                         CustomerID       Age  Annual Income ($)  \
# CustomerID                1.000000  0.070700           0.328400
# Age                       0.070700  1.000000           0.021378
# Annual Income ($)         0.328400  0.021378           1.000000
# Spending Score (1-100)    0.018936 -0.041798           0.023299
# Work Experience           0.091574 -0.014319           0.089136
# Family Size               0.159655  0.038254           0.093005
#
#                         Spending Score (1-100)  Work Experience  Family Size
# CustomerID                            0.018936         0.091574     0.159655
# Age                                  -0.041798        -0.014319     0.038254
# Annual Income ($)                     0.023299         0.089136     0.093005
# Spending Score (1-100)                1.000000        -0.028948     0.002232
# Work Experience                      -0.028948         1.000000     0.011873
# ...

# %%
plt.figure(figsize = (15,8))
heatmap = sns.heatmap(Cu.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Представлена тепловая карта

# %%
sns.scatterplot(data=Cu, y="Age", x="Spending Score (1-100)")
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Age'>

# %%
Cu.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
popular_gender = Cu['Gender'].mode()
mean_age=Cu['Age'].mean()
max_income=Cu['Annual Income ($)'].max()
min_income=Cu['Annual Income ($)'].min()
income_gender=Cu.groupby('Gender')['Annual Income ($)'].mean()
print("Популярный гендер:",popular_gender,"\n","средний возраст:",mean_age,"\b","Макс.доход:",max_income,"\n","Мин.доход:",min_income,"\n","Средний доход по гендеру:",income_gender)
# Out:
# Популярный гендер: 0    Female
# Name: Gender, dtype: object
#  Макс.доход: 189974
#  Мин.доход: 0
#  Средний доход по гендеру: Gender
# Female    110553.715008
# Male      110991.323096
# Name: Annual Income ($), dtype: float64

# %% [markdown]
# Вывод:
#
# * Датасет содержит 2000 записей и 8 столбцов
# * У 35 клиентов не определена профессия
# * Целевой признак 'Spending Score'
# * Большенство покупателей женщины
# * Большего всего художников,а меньше домохозяек
# * Большенство имеют стаж в 2 года
# * Большенство покупателей с размером семьи в 2 человека
# * Годовой доход самый маленький у профессии художник,наибольший у администратора
# * Показатель расходов в среднем  ~120000
# * Средний возраст: 48.96
# * Макс.доход: 189974
# * Средний доход по гендеру:
#   Female = 110553.715008
#   Male = 110991.323096

# %% [markdown]
# На основе полученных данных,можно предложить следующие:
# - магаизину неплохо бы взять во внимание художников,так как они являются обеспеченными и могут повысть прибыль магазина(предложить выгодные условия)
# - Так же женщин больше,следовательно предложить товары для женщин
# - Товары для семей скорее всего не пользуются спросом,так как в среднем 2 человека на семью,поэтому можно снизить закупку таких товаров

# %% [markdown]
# **Изучив датасет,на основе полученных значений,можно составить прогноз и предложения по дальнейшему улучшению качества и прибыльности магазина**
